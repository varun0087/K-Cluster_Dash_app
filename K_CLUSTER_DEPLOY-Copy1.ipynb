# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

import plotly.express as px

import dash
from dash.dependencies import Input, Output, State
from dash import dcc, html, dash_table

import pandas as pd

import dash_bootstrap_components as dbc
import matplotlib.pyplot as plt
import plotly.express as px
from jupyter_dash import JupyterDash

# %%
import plotly.graph_objects as go

# %%
df=pd.read_csv("data.csv")
#droping columns with categorical features
df.select_dtypes('object')
df.drop(columns='private', inplace=True,axis=1)
#top 10 variance features
top_10=df.var().sort_values().tail(10)

features=top_10.tail().index.to_list()
X=df[features]

# %%
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
app.layout=html.Div([
    
    html.H1("K-Means_Clustering",style={"textAlign":'center',"color":'blue'}),
    html.Br(),
    html.Br(),
    
    dbc.Row([
        
        dbc.Col([
            dbc.Row([
                dbc.Label("Select X-variable",style={"marginLeft":'10px','padding':'20px'}),
                dcc.Dropdown(id='x1',options=[
                        {"label": col, "value": col} for col in X.columns
                    ],value=features[0],style={"marginLeft":'10px','padding':'10px'})
            ]),
            html.Br(),
            dbc.Row([
                dbc.Label("Select Y-variable",style={"marginLeft":'10px','padding':'20px'}),
                dcc.Dropdown(id='x2',options=[
                        {"label": col, "value": col} for col in X.columns
                    ],value=features[1],style={"marginLeft":'10px','padding':'10px'})
            ]),
            html.Br(),
            dbc.Row([
                dbc.Label("Select n_Clusters",style={"marginLeft":'10px'}),
                dcc.Input(id='num',min=2,max=15,step=1,value=2,type='number',style={"marginLeft":'10px','padding':'10px'})
            ]),
            
            
            
            
        ],width=3),
        
        dbc.Col([
            
            dcc.Graph(id='figu')
            
        ],width=8),
        
        
    ],),
    
    
    
    
    
    
    
])


from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler


@app.callback(Output('figu','figure'),
             [Input('x1','value'),
             Input('x2','value'),
             Input('num','value')])
def make_graph(x, y, n_clusters):
    # minimal input validation, make sure there's at least one cluster
    km = KMeans(n_clusters=n_clusters)
    
    km.fit(X)
    X["cluster"] = km.labels_

    centers = km.cluster_centers_

    data = [
        go.Scatter(
            x=X.loc[X.cluster == c, x],
            y=X.loc[X.cluster == c, y],
            mode="markers",
        
            marker={"size": 8},
            name="Cluster {}".format(c),
        )
        for c in range(n_clusters)
    ]

    data.append(
        go.Scatter(
            x=centers[:, 0],
            y=centers[:, 1],
            mode="markers",
            marker={"color": "#000", "size": 12, "symbol": "diamond"},
            name="Cluster centers",
        )
    )

    layout = {"xaxis": {"title": x}, "yaxis": {"title": y}}
    

    return go.Figure(data=data, layout=layout)

# %%
if __name__ == "__main__":
    app.run_server(port='8080')
# Out:
# Dash is running on http://127.0.0.1:8080/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8080/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_2m1681120507.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_2m1681120507.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v1_4_1m1681677987.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_1m1681120507.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/deps/react@16.v2_9_2m1681120507.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_9_1m1681120507.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_9_2m1681120507.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_2m1681120507.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_10m1681120507.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:19] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_4m1681120507.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:20] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:20] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:20] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:20] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2023 01:11:20] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:11:38] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:11:44] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:11:45] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:11:49] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:11:52] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:11:54] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:05] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:07] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:10] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:14] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\varun\AppData\Local\Temp\ipykernel_1476\2610109725.py:69: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 127.0.0.1 - - [14/May/2023 01:12:15] "POST /_dash-update-component HTTP/1.1" 200 -
